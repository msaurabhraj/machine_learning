# %% [markdown]
# # NAME-AYUSH KUMAR

# %% [markdown]
# # SECTION - A

# %% [markdown]
# # SRN-PES1PG22CA037

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('diabetes.csv')

# %%
df.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0          6.0    148.0           72.0           35.0      0.0  33.6
# 1          1.0     85.0           66.0           29.0      0.0  26.6
# 2          8.0    183.0           64.0            NaN      0.0  23.3
# 3          1.0     89.0           66.0           23.0     94.0  28.1
# 4          0.0    137.0           40.0           35.0    168.0  43.1
#
#    DiabetesPedigreeFunction   Age  Outcome
# 0                     0.627  50.0      1.0
# 1                     0.351  31.0      0.0
# 2                     0.672  32.0      1.0
# 3                     0.167  21.0      0.0
# 4                     2.288  33.0      1.0

# %%
df.isna().head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin    BMI  \
# 0        False    False          False          False    False  False
# 1        False    False          False          False    False  False
# 2        False    False          False           True    False  False
# 3        False    False          False          False    False  False
# 4        False    False          False          False    False  False
#
#    DiabetesPedigreeFunction    Age  Outcome
# 0                     False  False    False
# 1                     False  False    False
# 2                     False  False    False
# 3                     False  False    False
# 4                     False  False    False

# %%
pd.NA

# %%
# df.notnull()

# %% [markdown]
# # Handling Null values

# %%
df.mean()
# Out:
# Pregnancies                   3.838548
# Glucose                     121.820126
# BloodPressure                72.451571
# SkinThickness                29.244248
# Insulin                      80.638298
# BMI                          32.446193
# DiabetesPedigreeFunction      0.470686
# Age                          33.195244
# Outcome                       0.350438
# dtype: float64

# %%
df['Pregnancies']=df['Pregnancies'].fillna(df['Pregnancies'].mean())
df['Glucose']=df['Glucose'].fillna(df['Glucose'].mean())
df['BloodPressure']=df['BloodPressure'].fillna(df['BloodPressure'].mean())
df['SkinThickness']=df['SkinThickness'].fillna(df['SkinThickness'].mean())
df['Insulin']=df['Insulin'].fillna(df['Insulin'].mean())
df['BMI']=df['BMI'].fillna(df['BMI'].mean())
df['DiabetesPedigreeFunction']=df['DiabetesPedigreeFunction'].fillna(df['DiabetesPedigreeFunction'].mean())
df['Age']=df['Age'].fillna(df['Age'].mean())
df['Outcome']=df['Outcome'].fillna(df['Outcome'].mean())

# %%
# df
df.isna().sum()
# Out:
# Pregnancies                 0
# Glucose                     0
# BloodPressure               0
# SkinThickness               0
# Insulin                     0
# BMI                         0
# DiabetesPedigreeFunction    0
# Age                         0
# Outcome                     0
# dtype: int64

# %%
df.tail()
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness     Insulin  \
# 795          8.0    167.0          106.0           46.0  231.000000
# 796          9.0    145.0           80.0           46.0  130.000000
# 797          6.0    115.0           60.0           39.0    0.000000
# 798          1.0    112.0           80.0           45.0  132.000000
# 799          4.0    145.0           82.0           18.0   80.638298
#
#            BMI  DiabetesPedigreeFunction        Age   Outcome
# 795  37.600000                  0.165000  43.000000  1.000000
# 796  37.900000                  0.637000  40.000000  1.000000
# 797  33.700000                  0.245000  40.000000  1.000000
# 798  34.800000                  0.217000  24.000000  0.000000
# 799  32.446193                  0.470686  33.195244  0.350438

# %%
plt.figure(figsize=(8,8),dpi=200)
sns.pairplot(df)

# %%
sns.displot(df)

# %% [markdown]
# # Feature Scaling

# %%
x=df.drop('Outcome',axis=1)
y = df['Outcome']

# %%
x.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0          6.0    148.0           72.0      35.000000      0.0  33.6
# 1          1.0     85.0           66.0      29.000000      0.0  26.6
# 2          8.0    183.0           64.0      29.244248      0.0  23.3
# 3          1.0     89.0           66.0      23.000000     94.0  28.1
# 4          0.0    137.0           40.0      35.000000    168.0  43.1
#
#    DiabetesPedigreeFunction   Age
# 0                     0.627  50.0
# 1                     0.351  31.0
# 2                     0.672  32.0
# 3                     0.167  21.0
# 4                     2.288  33.0

# %%
y.head()
# Out:
# 0    1.0
# 1    0.0
# 2    1.0
# 3    0.0
# 4    1.0
# Name: Outcome, dtype: float64

# %%
from sklearn.model_selection import train_test_split

# %%
 X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.25, random_state=0)
 X_train.shape,X_test.shape
# Out:
# ((600, 8), (200, 8))

# %%
plt.figure(figsize=(12,6))
cor = x.corr()

sns.heatmap(cor,annot=True)
# Out:
# <Axes: >

# %%
# X_train.head()
X_train.corr()
# Out:
#                           Pregnancies   Glucose  BloodPressure  SkinThickness  \
# Pregnancies                  1.000000  0.133955       0.210601       0.055108
# Glucose                      0.133955  1.000000       0.208289       0.188342
# BloodPressure                0.210601  0.208289       1.000000       0.175878
# SkinThickness                0.055108  0.188342       0.175878       1.000000
# Insulin                     -0.062708  0.345188      -0.049258       0.114981
# BMI                          0.018228  0.255648       0.282605       0.547704
# DiabetesPedigreeFunction    -0.054145  0.122684      -0.011774       0.091317
# Age                          0.543486  0.294634       0.321786       0.102617
#
#                            Insulin       BMI  DiabetesPedigreeFunction  \
# Pregnancies              -0.062708  0.018228                 -0.054145
# Glucose                   0.345188  0.255648                  0.122684
# ...

# %%
# def Correlation(dataset,threshold):
#     col_corr = set()
#     corr_matrix = dataset.corr()
#     for i in range(len(corr_matrix.columns)):
#         for j in range(i):
#             if abs(corr_matrix.iloc[i,j]>threshold):
#                 colname = corr_matrix.colunms[i]
#                 col_corr.add(colname)
#             return col_corr

# %%
# corr_features = Correlation(X_train,0.9)
# len(corr_features)

# %%
from sklearn.feature_selection import SelectKBest,f_regression

# %%
X=df.drop('Outcome',axis=1)
y = df['Outcome']
# x.head(),y.head()

# %%
#selecting best 5 features
bestfeatures = SelectKBest(f_regression,k=5)
X_new = bestfeatures.fit_transform(X,y)

# %%
X_new
# Out:
# array([[  6.        , 148.        ,  35.        ,  33.6       ,
#          50.        ],
#        [  1.        ,  85.        ,  29.        ,  26.6       ,
#          31.        ],
#        [  8.        , 183.        ,  29.24424779,  23.3       ,
#          32.        ],
#        ...,
#        [  6.        , 115.        ,  39.        ,  33.7       ,
#          40.        ],
#        [  1.        , 112.        ,  45.        ,  34.8       ,
#          24.        ],
#        [  4.        , 145.        ,  18.        ,  32.44619289,
#          33.19524406]])

# %%
#Best 5 features
x=pd.DataFrame(X_new)

# %%
x.head()
# Out:
#      0      1          2     3     4
# 0  6.0  148.0  35.000000  33.6  50.0
# 1  1.0   85.0  29.000000  26.6  31.0
# 2  8.0  183.0  29.244248  23.3  32.0
# 3  1.0   89.0  23.000000  28.1  21.0
# 4  0.0  137.0  35.000000  43.1  33.0

# %%
#correlation of new data
plt.figure(figsize=(12,6))
cor = x.corr()
sns.heatmap(cor,annot=True)
# Out:
# <Axes: >

# %%
cor
# Out:
#           0         1         2         3         4
# 0  1.000000  0.128808  0.091209  0.026416  0.551500
# 1  0.128808  1.000000  0.197866  0.236122  0.264034
# 2  0.091209  0.197866  1.000000  0.542099  0.129871
# 3  0.026416  0.236122  0.542099  1.000000  0.026370
# 4  0.551500  0.264034  0.129871  0.026370  1.000000

# %%
df2 = x

# %%
df2[5]=y

# %%
df2.head()
# Out:
#      0      1          2     3     4    5
# 0  6.0  148.0  35.000000  33.6  50.0  1.0
# 1  1.0   85.0  29.000000  26.6  31.0  0.0
# 2  8.0  183.0  29.244248  23.3  32.0  1.0
# 3  1.0   89.0  23.000000  28.1  21.0  0.0
# 4  0.0  137.0  35.000000  43.1  33.0  1.0

# %% [markdown]
# # Standard Scaling of Data

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler = StandardScaler()

# %%
scaled_X=scaler.fit_transform(df2)

# %%
scaled_X
# Out:
# array([[ 6.42915879e-01,  8.62074132e-01,  6.54187927e-01,
#          1.68943095e-01,  1.43971596e+00,  1.36231101e+00],
#        [-8.44315700e-01, -1.21244578e+00, -2.77607423e-02,
#         -8.56013032e-01, -1.88073419e-01, -7.34965478e-01],
#        [ 1.23780851e+00,  2.01458519e+00, -4.03794728e-16,
#         -1.33920664e+00, -1.02400294e-01,  1.36231101e+00],
#        ...,
#        [ 6.42915879e-01, -2.24579154e-01,  1.10882037e+00,
#          1.83585325e-01,  5.82984709e-01,  1.36231101e+00],
#        [-8.44315700e-01, -3.23365817e-01,  1.79076904e+00,
#          3.44649859e-01, -7.87785297e-01, -7.34965478e-01],
#        [ 4.80232475e-02,  7.63287469e-01, -1.27799997e+00,
#          0.00000000e+00,  0.00000000e+00, -1.16422232e-16]])

# %%
df3=pd.DataFrame(scaled_X)

# %%
df3.head()
# Out:
#           0         1             2         3         4         5
# 0  0.642916  0.862074  6.541879e-01  0.168943  1.439716  1.362311
# 1 -0.844316 -1.212446 -2.776074e-02 -0.856013 -0.188073 -0.734965
# 2  1.237809  2.014585 -4.037947e-16 -1.339207 -0.102400  1.362311
# 3 -0.844316 -1.080730 -7.097094e-01 -0.636380 -1.044805 -0.734965
# 4 -1.141762  0.499856  6.541879e-01  1.559955 -0.016727  1.362311

# %% [markdown]
# # PCA

# %%
from sklearn.decomposition import PCA

# %%
pca = PCA(n_components=2)

# %%
pca_model=pca.fit_transform(scaled_X)

# %%
pca_model
# Out:
# array([[ 2.13446418, -0.67845352],
#        [-1.59802951,  0.05384701],
#        [ 1.40594713, -1.20016854],
#        ...,
#        [ 1.50393941, -0.0632515 ],
#        [-0.25235094,  1.74782278],
#        [-0.14505669, -0.5312204 ]])

# %%
df4=pd.DataFrame(pca_model)

# %%
df4['outcome']=df['Outcome']

# %%
df4.tail(40)
# Out:
#             0         1   outcome
# 760 -1.781208  0.292523  0.000000
# 761  2.947593 -0.243802  1.000000
# 762 -0.884629 -1.621932  0.000000
# 763  1.818714 -1.471206  0.000000
# 764 -0.591630  0.768747  0.000000
# 765 -0.988096 -0.828401  0.000000
# 766  0.748054 -0.281730  1.000000
# 767 -1.439181  0.795957  0.000000
# 768  0.479326 -0.273992  1.000000
# 769 -0.212940 -1.165894  0.000000
# 770 -1.832880  0.117693  0.000000
# 771  1.178333  0.328269  1.000000
# 772 -2.642151 -1.120583  0.000000
# 773 -1.962898  0.050839  0.000000
# 774 -0.443569  0.503178  0.000000
# 775  1.628396 -1.253083  1.000000
# 776 -1.128862 -0.312127  0.000000
# 777 -1.162177  0.045810  0.000000
# 778  0.525222  1.230359  0.000000
# 779 -0.045660 -0.688779  1.000000
# 780  1.335542  1.935642  1.000000
# 781  1.897707 -1.533702  1.000000
# 782 -1.832533  0.391948  0.000000
# 783 -2.033853  0.127193  0.000000
# 784 -1.116566  0.516498  0.000000
# 785  0.184881  0.644373  0.000000
# ...

# %%
plt.figure(figsize=(6,6),dpi=200)#width ,height
plt.scatter(pca_model[:,0],pca_model[:,1],c=df4['outcome'])

# %%
x=df4.drop('outcome',axis=1)

# %%
y=df4['outcome']

# %%
x.head()
# Out:
#           0         1
# 0  2.134464 -0.678454
# 1 -1.598030  0.053847
# 2  1.405947 -1.200169
# 3 -2.052112  0.337896
# 4  1.345213  1.754388

# %%
y.head()
# Out:
# 0    1.0
# 1    0.0
# 2    1.0
# 3    0.0
# 4    1.0
# Name: outcome, dtype: float64

# %% [markdown]
# # Training and testing the data

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.25, random_state=0)

# %%
print(y_train.shape)
print(X_train.shape)
print(X_test.shape)
print(y_test.shape)
# Out:
# (600,)
# (600, 2)
# (200, 2)
# (200,)

# %%
from sklearn.linear_model import LinearRegression

# %%
model = LinearRegression()

# %%
model.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
test_predictions=model.predict(X_test)

# %%
test_predictions
# Out:
# array([ 3.93470638e-01, -8.17698433e-02,  7.35228202e-01,  3.67089945e-01,
#         6.27566543e-01,  6.74605111e-01,  8.57571015e-01,  1.94853302e-01,
#         6.23817943e-02,  9.44260393e-01,  6.07037875e-01, -8.59101372e-02,
#         7.74157734e-01,  8.89579357e-01, -2.31575776e-01, -3.73249534e-01,
#         5.05727122e-01,  2.60963138e-01,  3.16073763e-01,  4.21253887e-01,
#         5.65515308e-01,  7.92502307e-02,  2.72834627e-01,  2.52261222e-01,
#         8.99997593e-02, -2.10747518e-01, -1.91090052e-01,  5.54517084e-01,
#         6.73079485e-01,  1.95406874e-01, -8.41606820e-02,  1.01161384e+00,
#         1.38489089e-01, -6.61171336e-03,  4.12101000e-01,  6.18868647e-01,
#         3.42676669e-01,  3.32851165e-01,  1.66823177e-01,  5.35440855e-01,
#         3.91775169e-01,  9.86226034e-01,  6.65058246e-01,  7.19181913e-01,
#         3.73721225e-01,  4.17765571e-01,  4.76209189e-01,  2.56051698e-01,
# ...

# %%
from sklearn.metrics import mean_squared_error,mean_absolute_error

# %%
mean_squared_error(y_true=y_test,y_pred=test_predictions)
# Out:
# 0.10822367297066726

# %%
mean_absolute_error(y_true=y_test,y_pred=test_predictions)
# Out:
# 0.27011653465326974

# %%
#root mean squared error
np.sqrt(mean_squared_error(y_true=y_test,y_pred=test_predictions))
# Out:
# 0.32897366607475936
